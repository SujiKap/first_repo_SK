# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import sys

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities

#convert the cities list to dataframe
cities = pd.DataFrame(cities, columns=["City"])

#Add columns needed
cities["Cloudiness"] = ""
cities["Country"] = ""
cities["Date"] = ""
cities["Humidity"] = ""
cities["Lat"] = ""
cities["Lng"] = ""
cities["Max Temp"] = ""
cities["Wind Speed"] = ""



#write the cities to csv file
cities.to_csv("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/cities.csv")

# grab a sample for development
#cities_20 = cities[:20]

# %%
# cities.head()
#cities_20.head()

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Test API for a city.
url = "http://api.openweathermap.org/data/2.5/weather?"
city="hilo"
query_url = f"{url}appid={api_key}&q={city}"
response = requests.get(query_url)
weather_json = response.json()
weather_json
# Out:
# {'coord': {'lon': -155.08, 'lat': 19.71},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 291.02,
#   'pressure': 1020,
#   'humidity': 82,
#   'temp_min': 289.26,
#   'temp_max': 292.15},
#  'visibility': 16093,
#  'wind': {'speed': 1.5, 'deg': 200},
#  'clouds': {'all': 90},
#  'dt': 1553254035,
#  'sys': {'type': 1,
#   'id': 7881,
#   'message': 0.0046,
#   'country': 'US',
#   'sunrise': 1553271758,
#   'sunset': 1553315500},
#  'id': 5855927,
#  'name': 'Hilo',
#  'cod': 200}

# %%
#Test for London
London_cloudiness = weather_json["clouds"]["all"]
London_cloudiness
London_country = weather_json["sys"]["country"]
London_country
London_dt = weather_json["dt"]
London_dt
London_Humidity = weather_json["main"]["humidity"]
London_Humidity
London_Lat = weather_json["coord"]["lat"]
London_Lat
London_lon = weather_json["coord"]["lon"]
London_lon
London_temp_max = weather_json["main"]["temp_max"]
London_temp_max
London_wind_speed = weather_json["wind"]["speed"]
London_wind_speed
# Out:
# 1.5

# %%
#create a params dict that will be updated with new city each iteration
params = {"key":api_key}

for index, row in cities.iterrows():
    base_url = "http://api.openweathermap.org/data/2.5/weather?"
    
    city = row["City"]
    
    #make request
    query_url = f"{base_url}appid={api_key}&q={city}"
    response = requests.get(query_url)
    weather_json = response.json()
    weather_json
    
    print(f"Gathering results for: {city}")
    
    #skip missing values
    try:
        
        cities.loc[index, "Cloudiness"] = weather_json["clouds"]["all"]
        cities.loc[index, "Country"] = weather_json["sys"]["country"]
        cities.loc[index, "Date"] = weather_json["dt"]
        cities.loc[index, "Humidity"] = weather_json["main"]["humidity"]
        cities.loc[index, "Lat"] = weather_json["coord"]["lat"]
        cities.loc[index, "Lng"] = weather_json["coord"]["lon"]
        cities.loc[index, "Max Temp"]= weather_json["main"]["temp_max"]
        cities.loc[index, "Wind Speed"] = weather_json["wind"]["speed"]
        
        print(f"Success! Results for {city} added to dataframe!!\n")
             
    except Exception:
        print(f"Missing result ...skipping {sys.exc_info()} \n")
    
    cities.to_csv("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/cities.csv")
# Out:
# Gathering results for: amapa
# Success! Results for amapa added to dataframe!!
#
# Gathering results for: tasiilaq
# Success! Results for tasiilaq added to dataframe!!
#
# Gathering results for: santa cruz
# Success! Results for santa cruz added to dataframe!!
#
# Gathering results for: lorengau
# Success! Results for lorengau added to dataframe!!
#
# Gathering results for: nome
# Success! Results for nome added to dataframe!!
#
# Gathering results for: ushuaia
# Success! Results for ushuaia added to dataframe!!
#
# Gathering results for: touros
# Success! Results for touros added to dataframe!!
#
# Gathering results for: louisbourg
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AD96D08>)
#
# Gathering results for: busselton
# Success! Results for busselton added to dataframe!!
#
# Gathering results for: jamestown
# Success! Results for jamestown added to dataframe!!
#
# Gathering results for: narsaq
# Success! Results for narsaq added to dataframe!!
#
# Gathering results for: ponta delgada
# Success! Results for ponta delgada added to dataframe!!
#
# Gathering results for: kodinsk
# Success! Results for kodinsk added to dataframe!!
#
# Gathering results for: srednekolymsk
# Success! Results for srednekolymsk added to dataframe!!
#
# Gathering results for: tyret pervaya
# Success! Results for tyret pervaya added to dataframe!!
#
# Gathering results for: saleaula
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF25748>)
#
# Gathering results for: wattegama
# Success! Results for wattegama added to dataframe!!
#
# Gathering results for: burns lake
# Success! Results for burns lake added to dataframe!!
#
# Gathering results for: kadykchan
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000ADDEDC8>)
#
# Gathering results for: yambio
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF2B548>)
#
# Gathering results for: cherskiy
# Success! Results for cherskiy added to dataframe!!
#
# Gathering results for: hithadhoo
# Success! Results for hithadhoo added to dataframe!!
#
# Gathering results for: norman wells
# Success! Results for norman wells added to dataframe!!
#
# Gathering results for: usagara
# Success! Results for usagara added to dataframe!!
#
# Gathering results for: punta arenas
# Success! Results for punta arenas added to dataframe!!
#
# Gathering results for: mataura
# Success! Results for mataura added to dataframe!!
#
# Gathering results for: pandan
# Success! Results for pandan added to dataframe!!
#
# Gathering results for: port alfred
# Success! Results for port alfred added to dataframe!!
#
# Gathering results for: kapaa
# Success! Results for kapaa added to dataframe!!
#
# Gathering results for: matara
# Success! Results for matara added to dataframe!!
#
# Gathering results for: khagrachari
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF2D688>)
#
# Gathering results for: lasa
# Success! Results for lasa added to dataframe!!
#
# Gathering results for: taolanaro
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF2F188>)
#
# Gathering results for: upernavik
# Success! Results for upernavik added to dataframe!!
#
# Gathering results for: husavik
# Success! Results for husavik added to dataframe!!
#
# Gathering results for: dikson
# Success! Results for dikson added to dataframe!!
#
# Gathering results for: grindavik
# Success! Results for grindavik added to dataframe!!
#
# Gathering results for: illoqqortoormiut
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF32388>)
#
# Gathering results for: mrirt
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF2D148>)
#
# Gathering results for: plerin
# Success! Results for plerin added to dataframe!!
#
# Gathering results for: puerto ayora
# Success! Results for puerto ayora added to dataframe!!
#
# Gathering results for: clyde river
# Success! Results for clyde river added to dataframe!!
#
# Gathering results for: hobart
# Success! Results for hobart added to dataframe!!
#
# Gathering results for: saint-augustin
# Success! Results for saint-augustin added to dataframe!!
#
# Gathering results for: longyearbyen
# Success! Results for longyearbyen added to dataframe!!
#
# Gathering results for: rikitea
# Success! Results for rikitea added to dataframe!!
#
# Gathering results for: salalah
# Success! Results for salalah added to dataframe!!
#
# Gathering results for: arti
# Success! Results for arti added to dataframe!!
#
# Gathering results for: palmas
# Success! Results for palmas added to dataframe!!
#
# Gathering results for: ancud
# Success! Results for ancud added to dataframe!!
#
# Gathering results for: krabi
# Success! Results for krabi added to dataframe!!
#
# Gathering results for: klaksvik
# Success! Results for klaksvik added to dataframe!!
#
# Gathering results for: vaini
# Success! Results for vaini added to dataframe!!
#
# Gathering results for: arklow
# Success! Results for arklow added to dataframe!!
#
# Gathering results for: adrar
# Success! Results for adrar added to dataframe!!
#
# Gathering results for: ilulissat
# Success! Results for ilulissat added to dataframe!!
#
# Gathering results for: qasigiannguit
# Success! Results for qasigiannguit added to dataframe!!
#
# Gathering results for: saint-philippe
# Success! Results for saint-philippe added to dataframe!!
#
# Gathering results for: iqaluit
# Success! Results for iqaluit added to dataframe!!
#
# Gathering results for: bredasdorp
# Success! Results for bredasdorp added to dataframe!!
#
# Gathering results for: castro
# Success! Results for castro added to dataframe!!
#
# Gathering results for: fortuna
# Success! Results for fortuna added to dataframe!!
#
# Gathering results for: tumannyy
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF2A448>)
#
# Gathering results for: kavieng
# Success! Results for kavieng added to dataframe!!
#
# Gathering results for: mar del plata
# Success! Results for mar del plata added to dataframe!!
#
# Gathering results for: sentyabrskiy
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF2A448>)
#
# Gathering results for: port hardy
# Success! Results for port hardy added to dataframe!!
#
# Gathering results for: ponta do sol
# Success! Results for ponta do sol added to dataframe!!
#
# Gathering results for: albany
# Success! Results for albany added to dataframe!!
#
# Gathering results for: erenhot
# Success! Results for erenhot added to dataframe!!
#
# Gathering results for: alugan
# Success! Results for alugan added to dataframe!!
#
# Gathering results for: simbahan
# Success! Results for simbahan added to dataframe!!
#
# Gathering results for: bluff
# Success! Results for bluff added to dataframe!!
#
# Gathering results for: wembley
# Success! Results for wembley added to dataframe!!
#
# Gathering results for: along
# Success! Results for along added to dataframe!!
#
# Gathering results for: falmouth
# Success! Results for falmouth added to dataframe!!
#
# Gathering results for: nikolskoye
# Success! Results for nikolskoye added to dataframe!!
#
# Gathering results for: cape town
# Success! Results for cape town added to dataframe!!
#
# Gathering results for: arraial do cabo
# Success! Results for arraial do cabo added to dataframe!!
#
# Gathering results for: ahipara
# Success! Results for ahipara added to dataframe!!
#
# Gathering results for: vila
# Success! Results for vila added to dataframe!!
#
# Gathering results for: rantepao
# Success! Results for rantepao added to dataframe!!
#
# Gathering results for: lamu
# Success! Results for lamu added to dataframe!!
#
# Gathering results for: thompson
# Success! Results for thompson added to dataframe!!
#
# Gathering results for: placerville
# Success! Results for placerville added to dataframe!!
#
# Gathering results for: chuy
# Success! Results for chuy added to dataframe!!
#
# Gathering results for: saskylakh
# Success! Results for saskylakh added to dataframe!!
#
# Gathering results for: torbay
# Success! Results for torbay added to dataframe!!
#
# Gathering results for: tahta
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF213C8>)
#
# Gathering results for: gloucester
# Success! Results for gloucester added to dataframe!!
# Gathering results for: tricase
# Success! Results for tricase added to dataframe!!
#
# Gathering results for: tsihombe
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF243C8>)
#
# Gathering results for: jinxiang
# Success! Results for jinxiang added to dataframe!!
#
# Gathering results for: kungurtug
# Success! Results for kungurtug added to dataframe!!
#
# Gathering results for: impfondo
# Success! Results for impfondo added to dataframe!!
#
# Gathering results for: cap malheureux
# Success! Results for cap malheureux added to dataframe!!
#
# Gathering results for: puerto del rosario
# Success! Results for puerto del rosario added to dataframe!!
#
# Gathering results for: portland
# Success! Results for portland added to dataframe!!
#
# Gathering results for: pangnirtung
# Success! Results for pangnirtung added to dataframe!!
#
# Gathering results for: dandong
# Success! Results for dandong added to dataframe!!
#
# Gathering results for: tuatapere
# Success! Results for tuatapere added to dataframe!!
#
# Gathering results for: burscheid
# Success! Results for burscheid added to dataframe!!
#
# Gathering results for: atuona
# Success! Results for atuona added to dataframe!!
#
# Gathering results for: port elizabeth
# Success! Results for port elizabeth added to dataframe!!
#
# Gathering results for: airai
# Success! Results for airai added to dataframe!!
#
# Gathering results for: dickson
# Success! Results for dickson added to dataframe!!
#
# Gathering results for: mulchen
# Success! Results for mulchen added to dataframe!!
#
# Gathering results for: dwarka
# Success! Results for dwarka added to dataframe!!
#
# Gathering results for: hilo
# Success! Results for hilo added to dataframe!!
#
# Gathering results for: los arabos
# Success! Results for los arabos added to dataframe!!
#
# Gathering results for: yellowknife
# Success! Results for yellowknife added to dataframe!!
#
# Gathering results for: umba
# Success! Results for umba added to dataframe!!
#
# Gathering results for: wanning
# Success! Results for wanning added to dataframe!!
#
# Gathering results for: alofi
# Success! Results for alofi added to dataframe!!
#
# Gathering results for: atar
# Success! Results for atar added to dataframe!!
#
# Gathering results for: namibe
# Success! Results for namibe added to dataframe!!
#
# Gathering results for: lipari
# Success! Results for lipari added to dataframe!!
#
# Gathering results for: beloha
# Success! Results for beloha added to dataframe!!
#
# Gathering results for: carnarvon
# Success! Results for carnarvon added to dataframe!!
#
# Gathering results for: qaanaaq
# Success! Results for qaanaaq added to dataframe!!
#
# Gathering results for: dumai
# Success! Results for dumai added to dataframe!!
#
# Gathering results for: guerrero negro
# Success! Results for guerrero negro added to dataframe!!
#
# Gathering results for: san patricio
# Success! Results for san patricio added to dataframe!!
#
# Gathering results for: geilo
# Success! Results for geilo added to dataframe!!
#
# Gathering results for: charters towers
# Success! Results for charters towers added to dataframe!!
#
# Gathering results for: kedrovyy
# Success! Results for kedrovyy added to dataframe!!
#
# Gathering results for: betul
# Success! Results for betul added to dataframe!!
#
# Gathering results for: fairbanks
# Success! Results for fairbanks added to dataframe!!
#
# Gathering results for: mehran
# Success! Results for mehran added to dataframe!!
#
# Gathering results for: sitka
# Success! Results for sitka added to dataframe!!
#
# Gathering results for: avarua
# Success! Results for avarua added to dataframe!!
#
# Gathering results for: cabras
# Success! Results for cabras added to dataframe!!
#
# Gathering results for: miandrivazo
# Success! Results for miandrivazo added to dataframe!!
#
# Gathering results for: provideniya
# Success! Results for provideniya added to dataframe!!
#
# Gathering results for: magistralnyy
# Success! Results for magistralnyy added to dataframe!!
#
# Gathering results for: lebu
# Success! Results for lebu added to dataframe!!
#
# Gathering results for: beisfjord
# Success! Results for beisfjord added to dataframe!!
#
# Gathering results for: hermanus
# Success! Results for hermanus added to dataframe!!
#
# Gathering results for: dongsheng
# Success! Results for dongsheng added to dataframe!!
#
# Gathering results for: esperance
# Success! Results for esperance added to dataframe!!
#
# Gathering results for: viedma
# Success! Results for viedma added to dataframe!!
#
# Gathering results for: fougamou
# Success! Results for fougamou added to dataframe!!
#
# Gathering results for: kulunda
# Success! Results for kulunda added to dataframe!!
#
# Gathering results for: homer
# Success! Results for homer added to dataframe!!
#
# Gathering results for: buariki
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24208>)
#
# Gathering results for: waverly
# Success! Results for waverly added to dataframe!!
#
# Gathering results for: beringovskiy
# Success! Results for beringovskiy added to dataframe!!
#
# Gathering results for: ribeira grande
# Success! Results for ribeira grande added to dataframe!!
#
# Gathering results for: shelburne
# Success! Results for shelburne added to dataframe!!
#
# Gathering results for: ulaangom
# Success! Results for ulaangom added to dataframe!!
#
# Gathering results for: tautira
# Success! Results for tautira added to dataframe!!
#
# Gathering results for: new norfolk
# Success! Results for new norfolk added to dataframe!!
#
# Gathering results for: amderma
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF31988>)
#
# Gathering results for: katsuura
# Success! Results for katsuura added to dataframe!!
#
# Gathering results for: east london
# Success! Results for east london added to dataframe!!
#
# Gathering results for: lata
# Success! Results for lata added to dataframe!!
#
# Gathering results for: kaitangata
# Success! Results for kaitangata added to dataframe!!
#
# Gathering results for: mwinilunga
# Success! Results for mwinilunga added to dataframe!!
#
# Gathering results for: la sarre
# Success! Results for la sarre added to dataframe!!
#
# Gathering results for: micheweni
# Success! Results for micheweni added to dataframe!!
#
# Gathering results for: bengkulu
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3B288>)
#
# Gathering results for: tomatlan
# Success! Results for tomatlan added to dataframe!!
#
# Gathering results for: baoro
# Success! Results for baoro added to dataframe!!
#
# Gathering results for: amzya
# Success! Results for amzya added to dataframe!!
#
# Gathering results for: chicama
# Success! Results for chicama added to dataframe!!
#
# Gathering results for: benguela
# Success! Results for benguela added to dataframe!!
#
# Gathering results for: rungata
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF31708>)
#
# Gathering results for: hasaki
# Success! Results for hasaki added to dataframe!!
#
# Gathering results for: morehead
# Success! Results for morehead added to dataframe!!
#
# Gathering results for: vila velha
# Success! Results for vila velha added to dataframe!!
#
# Gathering results for: mayo
# Success! Results for mayo added to dataframe!!
#
# Gathering results for: takestan
# Success! Results for takestan added to dataframe!!
#
# Gathering results for: butaritari
# Success! Results for butaritari added to dataframe!!
#
# Gathering results for: mankono
# Success! Results for mankono added to dataframe!!
#
# Gathering results for: pevek
# Success! Results for pevek added to dataframe!!
#
# Gathering results for: attawapiskat
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF21988>)
#
# Gathering results for: saint george
# Success! Results for saint george added to dataframe!!
#
# Gathering results for: gizo
# Success! Results for gizo added to dataframe!!
#
# Gathering results for: barrow
# Success! Results for barrow added to dataframe!!
#
# Gathering results for: itarema
# Success! Results for itarema added to dataframe!!
#
# Gathering results for: balclutha
# Success! Results for balclutha added to dataframe!!
#
# Gathering results for: le port
# Success! Results for le port added to dataframe!!
#
# Gathering results for: atambua
# Success! Results for atambua added to dataframe!!
#
# Gathering results for: banjarmasin
# Success! Results for banjarmasin added to dataframe!!
# Gathering results for: peniche
# Success! Results for peniche added to dataframe!!
#
# Gathering results for: bathsheba
# Success! Results for bathsheba added to dataframe!!
#
# Gathering results for: chokurdakh
# Success! Results for chokurdakh added to dataframe!!
#
# Gathering results for: san policarpo
# Success! Results for san policarpo added to dataframe!!
#
# Gathering results for: palmer
# Success! Results for palmer added to dataframe!!
#
# Gathering results for: faanui
# Success! Results for faanui added to dataframe!!
#
# Gathering results for: havre-saint-pierre
# Success! Results for havre-saint-pierre added to dataframe!!
#
# Gathering results for: townsville
# Success! Results for townsville added to dataframe!!
#
# Gathering results for: belyy
# Success! Results for belyy added to dataframe!!
#
# Gathering results for: fez
# Success! Results for fez added to dataframe!!
#
# Gathering results for: road town
# Success! Results for road town added to dataframe!!
#
# Gathering results for: bitung
# Success! Results for bitung added to dataframe!!
#
# Gathering results for: souillac
# Success! Results for souillac added to dataframe!!
#
# Gathering results for: boende
# Success! Results for boende added to dataframe!!
#
# Gathering results for: jahrom
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF21308>)
#
# Gathering results for: pisco
# Success! Results for pisco added to dataframe!!
#
# Gathering results for: ossora
# Success! Results for ossora added to dataframe!!
#
# Gathering results for: honiara
# Success! Results for honiara added to dataframe!!
#
# Gathering results for: bocaranga
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3AF08>)
#
# Gathering results for: pacific grove
# Success! Results for pacific grove added to dataframe!!
#
# Gathering results for: mys shmidta
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24508>)
#
# Gathering results for: nuuk
# Success! Results for nuuk added to dataframe!!
#
# Gathering results for: oblivskaya
# Success! Results for oblivskaya added to dataframe!!
#
# Gathering results for: tiksi
# Success! Results for tiksi added to dataframe!!
#
# Gathering results for: sagone
# Success! Results for sagone added to dataframe!!
#
# Gathering results for: fort nelson
# Success! Results for fort nelson added to dataframe!!
#
# Gathering results for: karaul
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3AE48>)
#
# Gathering results for: alta floresta
# Success! Results for alta floresta added to dataframe!!
#
# Gathering results for: barentsburg
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF40708>)
#
# Gathering results for: orlea
# Success! Results for orlea added to dataframe!!
#
# Gathering results for: waipawa
# Success! Results for waipawa added to dataframe!!
#
# Gathering results for: warqla
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF31648>)
#
# Gathering results for: nehe
# Success! Results for nehe added to dataframe!!
#
# Gathering results for: porbandar
# Success! Results for porbandar added to dataframe!!
#
# Gathering results for: mahebourg
# Success! Results for mahebourg added to dataframe!!
#
# Gathering results for: the valley
# Success! Results for the valley added to dataframe!!
#
# Gathering results for: qui nhon
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24448>)
#
# Gathering results for: kaeo
# Success! Results for kaeo added to dataframe!!
#
# Gathering results for: xuddur
# Success! Results for xuddur added to dataframe!!
#
# Gathering results for: aksu
# Success! Results for aksu added to dataframe!!
#
# Gathering results for: palana
# Success! Results for palana added to dataframe!!
#
# Gathering results for: antofagasta
# Success! Results for antofagasta added to dataframe!!
#
# Gathering results for: visby
# Success! Results for visby added to dataframe!!
#
# Gathering results for: leningradskiy
# Success! Results for leningradskiy added to dataframe!!
#
# Gathering results for: chinautla
# Success! Results for chinautla added to dataframe!!
#
# Gathering results for: kenai
# Success! Results for kenai added to dataframe!!
#
# Gathering results for: ouesso
# Success! Results for ouesso added to dataframe!!
#
# Gathering results for: virginia beach
# Success! Results for virginia beach added to dataframe!!
#
# Gathering results for: contai
# Success! Results for contai added to dataframe!!
#
# Gathering results for: maple creek
# Success! Results for maple creek added to dataframe!!
#
# Gathering results for: talnakh
# Success! Results for talnakh added to dataframe!!
#
# Gathering results for: malibu
# Success! Results for malibu added to dataframe!!
#
# Gathering results for: ikongo
# Success! Results for ikongo added to dataframe!!
#
# Gathering results for: marsa matruh
# Success! Results for marsa matruh added to dataframe!!
#
# Gathering results for: penzance
# Success! Results for penzance added to dataframe!!
#
# Gathering results for: makakilo city
# Success! Results for makakilo city added to dataframe!!
#
# Gathering results for: dunmore east
# Success! Results for dunmore east added to dataframe!!
#
# Gathering results for: noumea
# Success! Results for noumea added to dataframe!!
#
# Gathering results for: half moon bay
# Success! Results for half moon bay added to dataframe!!
#
# Gathering results for: mount gambier
# Success! Results for mount gambier added to dataframe!!
#
# Gathering results for: jiwani
# Success! Results for jiwani added to dataframe!!
#
# Gathering results for: lompoc
# Success! Results for lompoc added to dataframe!!
#
# Gathering results for: varberg
# Success! Results for varberg added to dataframe!!
#
# Gathering results for: abha
# Success! Results for abha added to dataframe!!
#
# Gathering results for: muros
# Success! Results for muros added to dataframe!!
#
# Gathering results for: port lincoln
# Success! Results for port lincoln added to dataframe!!
#
# Gathering results for: victoria
# Success! Results for victoria added to dataframe!!
#
# Gathering results for: tuktoyaktuk
# Success! Results for tuktoyaktuk added to dataframe!!
#
# Gathering results for: blackwater
# Success! Results for blackwater added to dataframe!!
#
# Gathering results for: cedar city
# Success! Results for cedar city added to dataframe!!
#
# Gathering results for: tura
# Success! Results for tura added to dataframe!!
#
# Gathering results for: serenje
# Success! Results for serenje added to dataframe!!
#
# Gathering results for: sobolevo
# Success! Results for sobolevo added to dataframe!!
#
# Gathering results for: pokaran
# Success! Results for pokaran added to dataframe!!
#
# Gathering results for: roald
# Success! Results for roald added to dataframe!!
#
# Gathering results for: khatanga
# Success! Results for khatanga added to dataframe!!
#
# Gathering results for: chirongui
# Success! Results for chirongui added to dataframe!!
#
# Gathering results for: quelimane
# Success! Results for quelimane added to dataframe!!
#
# Gathering results for: beckley
# Success! Results for beckley added to dataframe!!
#
# Gathering results for: el sauce
# Success! Results for el sauce added to dataframe!!
#
# Gathering results for: ayan
# Success! Results for ayan added to dataframe!!
#
# Gathering results for: roma
# Success! Results for roma added to dataframe!!
#
# Gathering results for: kirakira
# Success! Results for kirakira added to dataframe!!
#
# Gathering results for: vanimo
# Success! Results for vanimo added to dataframe!!
#
# Gathering results for: gamba
# Success! Results for gamba added to dataframe!!
#
# Gathering results for: brigantine
# Success! Results for brigantine added to dataframe!!
#
# Gathering results for: hami
# Success! Results for hami added to dataframe!!
#
# Gathering results for: hambantota
# Success! Results for hambantota added to dataframe!!
#
# Gathering results for: xuanzhou
# Success! Results for xuanzhou added to dataframe!!
#
# Gathering results for: tawkar
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3BE48>)
#
# Gathering results for: amalapuram
# Success! Results for amalapuram added to dataframe!!
#
# Gathering results for: san quintin
# Success! Results for san quintin added to dataframe!!
# Gathering results for: elban
# Success! Results for elban added to dataframe!!
#
# Gathering results for: coahuayana
# Success! Results for coahuayana added to dataframe!!
#
# Gathering results for: uglekamensk
# Success! Results for uglekamensk added to dataframe!!
#
# Gathering results for: lakes entrance
# Success! Results for lakes entrance added to dataframe!!
#
# Gathering results for: alappuzha
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24448>)
#
# Gathering results for: nizhneyansk
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF241C8>)
#
# Gathering results for: garden city
# Success! Results for garden city added to dataframe!!
#
# Gathering results for: lagoa
# Success! Results for lagoa added to dataframe!!
#
# Gathering results for: muhororo
# Success! Results for muhororo added to dataframe!!
#
# Gathering results for: bethel
# Success! Results for bethel added to dataframe!!
#
# Gathering results for: bambous virieux
# Success! Results for bambous virieux added to dataframe!!
#
# Gathering results for: teguldet
# Success! Results for teguldet added to dataframe!!
#
# Gathering results for: bowen
# Success! Results for bowen added to dataframe!!
#
# Gathering results for: parrita
# Success! Results for parrita added to dataframe!!
#
# Gathering results for: constitucion
# Success! Results for constitucion added to dataframe!!
#
# Gathering results for: kalmunai
# Success! Results for kalmunai added to dataframe!!
#
# Gathering results for: kodiak
# Success! Results for kodiak added to dataframe!!
#
# Gathering results for: san-pedro
# Success! Results for san-pedro added to dataframe!!
#
# Gathering results for: beyneu
# Success! Results for beyneu added to dataframe!!
#
# Gathering results for: villa carlos paz
# Success! Results for villa carlos paz added to dataframe!!
#
# Gathering results for: riyadh
# Success! Results for riyadh added to dataframe!!
#
# Gathering results for: sal rei
# Success! Results for sal rei added to dataframe!!
#
# Gathering results for: cehegin
# Success! Results for cehegin added to dataframe!!
#
# Gathering results for: kirensk
# Success! Results for kirensk added to dataframe!!
#
# Gathering results for: liverpool
# Success! Results for liverpool added to dataframe!!
#
# Gathering results for: codrington
# Success! Results for codrington added to dataframe!!
#
# Gathering results for: chiredzi
# Success! Results for chiredzi added to dataframe!!
#
# Gathering results for: pingyin
# Success! Results for pingyin added to dataframe!!
#
# Gathering results for: bosaso
# Success! Results for bosaso added to dataframe!!
#
# Gathering results for: dunedin
# Success! Results for dunedin added to dataframe!!
#
# Gathering results for: ramsar
# Success! Results for ramsar added to dataframe!!
#
# Gathering results for: mehamn
# Success! Results for mehamn added to dataframe!!
#
# Gathering results for: te anau
# Success! Results for te anau added to dataframe!!
#
# Gathering results for: erzin
# Success! Results for erzin added to dataframe!!
#
# Gathering results for: sorong
# Success! Results for sorong added to dataframe!!
#
# Gathering results for: halalo
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24588>)
#
# Gathering results for: challans
# Success! Results for challans added to dataframe!!
#
# Gathering results for: hofn
# Success! Results for hofn added to dataframe!!
#
# Gathering results for: bandarbeyla
# Success! Results for bandarbeyla added to dataframe!!
#
# Gathering results for: lavrentiya
# Success! Results for lavrentiya added to dataframe!!
#
# Gathering results for: wamba
# Success! Results for wamba added to dataframe!!
#
# Gathering results for: sao felix do xingu
# Success! Results for sao felix do xingu added to dataframe!!
#
# Gathering results for: khamgaon
# Success! Results for khamgaon added to dataframe!!
#
# Gathering results for: jega
# Success! Results for jega added to dataframe!!
#
# Gathering results for: nouakchott
# Success! Results for nouakchott added to dataframe!!
#
# Gathering results for: hernani
# Success! Results for hernani added to dataframe!!
#
# Gathering results for: vestmannaeyjar
# Success! Results for vestmannaeyjar added to dataframe!!
#
# Gathering results for: jawhar
# Success! Results for jawhar added to dataframe!!
#
# Gathering results for: shache
# Success! Results for shache added to dataframe!!
#
# Gathering results for: las vegas
# Success! Results for las vegas added to dataframe!!
#
# Gathering results for: aklavik
# Success! Results for aklavik added to dataframe!!
#
# Gathering results for: kuche
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24588>)
#
# Gathering results for: bereda
# Success! Results for bereda added to dataframe!!
#
# Gathering results for: krasnoselkup
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF31288>)
#
# Gathering results for: hammerfest
# Success! Results for hammerfest added to dataframe!!
#
# Gathering results for: pavda
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF21888>)
#
# Gathering results for: sabang
# Success! Results for sabang added to dataframe!!
#
# Gathering results for: port shepstone
# Success! Results for port shepstone added to dataframe!!
#
# Gathering results for: kysyl-syr
# Success! Results for kysyl-syr added to dataframe!!
#
# Gathering results for: la paz
# Success! Results for la paz added to dataframe!!
#
# Gathering results for: zemio
# Success! Results for zemio added to dataframe!!
#
# Gathering results for: wanaka
# Success! Results for wanaka added to dataframe!!
#
# Gathering results for: pierre
# Success! Results for pierre added to dataframe!!
#
# Gathering results for: asfi
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954188>)
#
# Gathering results for: vardo
# Success! Results for vardo added to dataframe!!
#
# Gathering results for: samusu
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954208>)
#
# Gathering results for: maceio
# Success! Results for maceio added to dataframe!!
#
# Gathering results for: tambacounda
# Success! Results for tambacounda added to dataframe!!
#
# Gathering results for: havoysund
# Success! Results for havoysund added to dataframe!!
#
# Gathering results for: plainview
# Success! Results for plainview added to dataframe!!
#
# Gathering results for: havelock
# Success! Results for havelock added to dataframe!!
#
# Gathering results for: beira
# Success! Results for beira added to dataframe!!
#
# Gathering results for: asau
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954248>)
#
# Gathering results for: tiznit
# Success! Results for tiznit added to dataframe!!
#
# Gathering results for: vaitupu
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF21488>)
#
# Gathering results for: suntar
# Success! Results for suntar added to dataframe!!
#
# Gathering results for: turiacu
# Success! Results for turiacu added to dataframe!!
#
# Gathering results for: kalat
# Success! Results for kalat added to dataframe!!
#
# Gathering results for: agropoli
# Success! Results for agropoli added to dataframe!!
#
# Gathering results for: madawaska
# Success! Results for madawaska added to dataframe!!
#
# Gathering results for: north bend
# Success! Results for north bend added to dataframe!!
#
# Gathering results for: port macquarie
# Success! Results for port macquarie added to dataframe!!
#
# Gathering results for: conceicao do araguaia
# Success! Results for conceicao do araguaia added to dataframe!!
#
# Gathering results for: makaha
# Success! Results for makaha added to dataframe!!
#
# Gathering results for: isangel
# Success! Results for isangel added to dataframe!!
#
# Gathering results for: georgetown
# Success! Results for georgetown added to dataframe!!
#
# Gathering results for: pula
# Success! Results for pula added to dataframe!!
#
# Gathering results for: palabuhanratu
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3A3C8>)
#
# Gathering results for: cabo san lucas
# Success! Results for cabo san lucas added to dataframe!!
#
# Gathering results for: anadyr
# Success! Results for anadyr added to dataframe!!
# Gathering results for: yangambi
# Success! Results for yangambi added to dataframe!!
#
# Gathering results for: acapulco
# Success! Results for acapulco added to dataframe!!
#
# Gathering results for: los llanos de aridane
# Success! Results for los llanos de aridane added to dataframe!!
#
# Gathering results for: bubaque
# Success! Results for bubaque added to dataframe!!
#
# Gathering results for: rudbar
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24708>)
#
# Gathering results for: komsomolskiy
# Success! Results for komsomolskiy added to dataframe!!
#
# Gathering results for: kisanga
# Success! Results for kisanga added to dataframe!!
#
# Gathering results for: prince rupert
# Success! Results for prince rupert added to dataframe!!
#
# Gathering results for: huesca
# Success! Results for huesca added to dataframe!!
#
# Gathering results for: vertientes
# Success! Results for vertientes added to dataframe!!
#
# Gathering results for: sinnamary
# Success! Results for sinnamary added to dataframe!!
#
# Gathering results for: vyyezdnoye
# Success! Results for vyyezdnoye added to dataframe!!
#
# Gathering results for: luderitz
# Success! Results for luderitz added to dataframe!!
#
# Gathering results for: magnitka
# Success! Results for magnitka added to dataframe!!
#
# Gathering results for: tvardica
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24688>)
#
# Gathering results for: saint-georges
# Success! Results for saint-georges added to dataframe!!
#
# Gathering results for: padang
# Success! Results for padang added to dataframe!!
#
# Gathering results for: cayenne
# Success! Results for cayenne added to dataframe!!
#
# Gathering results for: umm kaddadah
# Success! Results for umm kaddadah added to dataframe!!
#
# Gathering results for: adwa
# Success! Results for adwa added to dataframe!!
#
# Gathering results for: petropavlovsk-kamchatskiy
# Success! Results for petropavlovsk-kamchatskiy added to dataframe!!
#
# Gathering results for: tilichiki
# Success! Results for tilichiki added to dataframe!!
#
# Gathering results for: kavaratti
# Success! Results for kavaratti added to dataframe!!
#
# Gathering results for: avera
# Success! Results for avera added to dataframe!!
#
# Gathering results for: geraldton
# Success! Results for geraldton added to dataframe!!
#
# Gathering results for: sangrur
# Success! Results for sangrur added to dataframe!!
#
# Gathering results for: turinsk
# Success! Results for turinsk added to dataframe!!
#
# Gathering results for: oranjemund
# Success! Results for oranjemund added to dataframe!!
#
# Gathering results for: vostok
# Success! Results for vostok added to dataframe!!
#
# Gathering results for: cockburn harbour
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954208>)
#
# Gathering results for: lebyazhye
# Success! Results for lebyazhye added to dataframe!!
#
# Gathering results for: kahului
# Success! Results for kahului added to dataframe!!
#
# Gathering results for: dryden
# Success! Results for dryden added to dataframe!!
#
# Gathering results for: verkhoturye
# Success! Results for verkhoturye added to dataframe!!
#
# Gathering results for: namatanai
# Success! Results for namatanai added to dataframe!!
#
# Gathering results for: chapleau
# Success! Results for chapleau added to dataframe!!
#
# Gathering results for: maumere
# Success! Results for maumere added to dataframe!!
#
# Gathering results for: labuhan
# Success! Results for labuhan added to dataframe!!
#
# Gathering results for: belushya guba
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954208>)
#
# Gathering results for: vanavara
# Success! Results for vanavara added to dataframe!!
#
# Gathering results for: ballina
# Success! Results for ballina added to dataframe!!
#
# Gathering results for: pacifica
# Success! Results for pacifica added to dataframe!!
#
# Gathering results for: tromso
# Success! Results for tromso added to dataframe!!
#
# Gathering results for: archidona
# Success! Results for archidona added to dataframe!!
#
# Gathering results for: shenandoah
# Success! Results for shenandoah added to dataframe!!
#
# Gathering results for: shieli
# Success! Results for shieli added to dataframe!!
#
# Gathering results for: naze
# Success! Results for naze added to dataframe!!
#
# Gathering results for: oga
# Success! Results for oga added to dataframe!!
#
# Gathering results for: balabac
# Success! Results for balabac added to dataframe!!
#
# Gathering results for: gambela
# Success! Results for gambela added to dataframe!!
#
# Gathering results for: burnie
# Success! Results for burnie added to dataframe!!
#
# Gathering results for: evensk
# Success! Results for evensk added to dataframe!!
#
# Gathering results for: atasu
# Success! Results for atasu added to dataframe!!
#
# Gathering results for: sabaudia
# Success! Results for sabaudia added to dataframe!!
#
# Gathering results for: cidreira
# Success! Results for cidreira added to dataframe!!
#
# Gathering results for: boguchany
# Success! Results for boguchany added to dataframe!!
#
# Gathering results for: araouane
# Success! Results for araouane added to dataframe!!
#
# Gathering results for: buriti alegre
# Success! Results for buriti alegre added to dataframe!!
#
# Gathering results for: richards bay
# Success! Results for richards bay added to dataframe!!
#
# Gathering results for: gudari
# Success! Results for gudari added to dataframe!!
#
# Gathering results for: biak
# Success! Results for biak added to dataframe!!
#
# Gathering results for: iquitos
# Success! Results for iquitos added to dataframe!!
#
# Gathering results for: vylgort
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF241C8>)
#
# Gathering results for: san jeronimo
# Success! Results for san jeronimo added to dataframe!!
#
# Gathering results for: kalinagar
# Success! Results for kalinagar added to dataframe!!
#
# Gathering results for: nantucket
# Success! Results for nantucket added to dataframe!!
#
# Gathering results for: port-gentil
# Success! Results for port-gentil added to dataframe!!
#
# Gathering results for: sao filipe
# Success! Results for sao filipe added to dataframe!!
#
# Gathering results for: henties bay
# Success! Results for henties bay added to dataframe!!
#
# Gathering results for: pousat
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954208>)
#
# Gathering results for: yerkoy
# Success! Results for yerkoy added to dataframe!!
#
# Gathering results for: karratha
# Success! Results for karratha added to dataframe!!
#
# Gathering results for: mackay
# Success! Results for mackay added to dataframe!!
#
# Gathering results for: stromness
# Success! Results for stromness added to dataframe!!
#
# Gathering results for: dennery
# Success! Results for dennery added to dataframe!!
#
# Gathering results for: samarai
# Success! Results for samarai added to dataframe!!
#
# Gathering results for: mimongo
# Success! Results for mimongo added to dataframe!!
#
# Gathering results for: overyata
# Success! Results for overyata added to dataframe!!
#
# Gathering results for: port keats
# Success! Results for port keats added to dataframe!!
#
# Gathering results for: belaya gora
# Success! Results for belaya gora added to dataframe!!
#
# Gathering results for: bontang
# Success! Results for bontang added to dataframe!!
#
# Gathering results for: celestun
# Success! Results for celestun added to dataframe!!
#
# Gathering results for: quatre cocos
# Success! Results for quatre cocos added to dataframe!!
#
# Gathering results for: fresnillo
# Success! Results for fresnillo added to dataframe!!
#
# Gathering results for: aranda de duero
# Success! Results for aranda de duero added to dataframe!!
#
# Gathering results for: deputatskiy
# Success! Results for deputatskiy added to dataframe!!
#
# Gathering results for: kirillov
# Success! Results for kirillov added to dataframe!!
#
# Gathering results for: lahij
# Success! Results for lahij added to dataframe!!
#
# Gathering results for: raudeberg
# Success! Results for raudeberg added to dataframe!!
#
# Gathering results for: wenatchee
# Success! Results for wenatchee added to dataframe!!
#
# Gathering results for: dzilam gonzalez
# Success! Results for dzilam gonzalez added to dataframe!!
#
# Gathering results for: mayumba
# Success! Results for mayumba added to dataframe!!
# Gathering results for: khani
# Success! Results for khani added to dataframe!!
#
# Gathering results for: camacha
# Success! Results for camacha added to dataframe!!
#
# Gathering results for: honningsvag
# Success! Results for honningsvag added to dataframe!!
#
# Gathering results for: culpeper
# Success! Results for culpeper added to dataframe!!
#
# Gathering results for: bah
# Success! Results for bah added to dataframe!!
#
# Gathering results for: berlevag
# Success! Results for berlevag added to dataframe!!
#
# Gathering results for: gushikawa
# Success! Results for gushikawa added to dataframe!!
#
# Gathering results for: todos santos
# Success! Results for todos santos added to dataframe!!
#
# Gathering results for: rio grande
# Success! Results for rio grande added to dataframe!!
#
# Gathering results for: barcelos
# Success! Results for barcelos added to dataframe!!
#
# Gathering results for: whitehorse
# Success! Results for whitehorse added to dataframe!!
#
# Gathering results for: vangaindrano
# Success! Results for vangaindrano added to dataframe!!
#
# Gathering results for: tamandare
# Success! Results for tamandare added to dataframe!!
#
# Gathering results for: vallenar
# Success! Results for vallenar added to dataframe!!
#
# Gathering results for: turinskaya sloboda
# Success! Results for turinskaya sloboda added to dataframe!!
#
# Gathering results for: malanje
# Success! Results for malanje added to dataframe!!
#
# Gathering results for: alzamay
# Success! Results for alzamay added to dataframe!!
#
# Gathering results for: ngunguru
# Success! Results for ngunguru added to dataframe!!
#
# Gathering results for: igrim
# Success! Results for igrim added to dataframe!!
#
# Gathering results for: lanzhou
# Success! Results for lanzhou added to dataframe!!
#
# Gathering results for: sibolga
# Success! Results for sibolga added to dataframe!!
#
# Gathering results for: mandalgovi
# Success! Results for mandalgovi added to dataframe!!
#
# Gathering results for: iskilip
# Success! Results for iskilip added to dataframe!!
#
# Gathering results for: rock springs
# Success! Results for rock springs added to dataframe!!
#
# Gathering results for: arlit
# Success! Results for arlit added to dataframe!!
#
# Gathering results for: ostrovnoy
# Success! Results for ostrovnoy added to dataframe!!
#
# Gathering results for: solovetskiy
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954948>)
#
# Gathering results for: elizabethtown
# Success! Results for elizabethtown added to dataframe!!
#
# Gathering results for: grand-santi
# Success! Results for grand-santi added to dataframe!!
#
# Gathering results for: yar-sale
# Success! Results for yar-sale added to dataframe!!
#
# Gathering results for: toliary
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF31308>)
#
# Gathering results for: caravelas
# Success! Results for caravelas added to dataframe!!
#
# Gathering results for: tanout
# Success! Results for tanout added to dataframe!!
#
# Gathering results for: san vicente
# Success! Results for san vicente added to dataframe!!
#
# Gathering results for: san fernando
# Success! Results for san fernando added to dataframe!!
#
# Gathering results for: lovozero
# Success! Results for lovozero added to dataframe!!
#
# Gathering results for: sur
# Success! Results for sur added to dataframe!!
#
# Gathering results for: vestmanna
# Success! Results for vestmanna added to dataframe!!
#
# Gathering results for: bendigo
# Success! Results for bendigo added to dataframe!!
#
# Gathering results for: otjimbingwe
# Success! Results for otjimbingwe added to dataframe!!
#
# Gathering results for: katherine
# Success! Results for katherine added to dataframe!!
#
# Gathering results for: wooster
# Success! Results for wooster added to dataframe!!
#
# Gathering results for: ahuimanu
# Success! Results for ahuimanu added to dataframe!!
#
# Gathering results for: fevralsk
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954188>)
#
# Gathering results for: zapolyarnyy
# Success! Results for zapolyarnyy added to dataframe!!
#
# Gathering results for: saldanha
# Success! Results for saldanha added to dataframe!!
#
# Gathering results for: benghazi
# Success! Results for benghazi added to dataframe!!
#
# Gathering results for: nouadhibou
# Success! Results for nouadhibou added to dataframe!!
#
# Gathering results for: viligili
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3AC08>)
#
# Gathering results for: moju
# Success! Results for moju added to dataframe!!
#
# Gathering results for: maraba
# Success! Results for maraba added to dataframe!!
#
# Gathering results for: puerto colombia
# Success! Results for puerto colombia added to dataframe!!
#
# Gathering results for: youghal
# Success! Results for youghal added to dataframe!!
#
# Gathering results for: margate
# Success! Results for margate added to dataframe!!
#
# Gathering results for: bandiagara
# Success! Results for bandiagara added to dataframe!!
#
# Gathering results for: pedernales
# Success! Results for pedernales added to dataframe!!
#
# Gathering results for: wellington
# Success! Results for wellington added to dataframe!!
#
# Gathering results for: manta
# Success! Results for manta added to dataframe!!
#
# Gathering results for: insar
# Success! Results for insar added to dataframe!!
#
# Gathering results for: novikovo
# Success! Results for novikovo added to dataframe!!
#
# Gathering results for: phan rang
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002956808>)
#
# Gathering results for: sisimiut
# Success! Results for sisimiut added to dataframe!!
#
# Gathering results for: baruun-urt
# Success! Results for baruun-urt added to dataframe!!
#
# Gathering results for: newcastle
# Success! Results for newcastle added to dataframe!!
#
# Gathering results for: mirador
# Success! Results for mirador added to dataframe!!
#
# Gathering results for: coos bay
# Success! Results for coos bay added to dataframe!!
#
# Gathering results for: grand river south east
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3B088>)
#
# Gathering results for: ketchikan
# Success! Results for ketchikan added to dataframe!!
#
# Gathering results for: cururupu
# Success! Results for cururupu added to dataframe!!
#
# Gathering results for: vadlapudi
# Success! Results for vadlapudi added to dataframe!!
#
# Gathering results for: bikapur
# Success! Results for bikapur added to dataframe!!
#
# Gathering results for: waynesboro
# Success! Results for waynesboro added to dataframe!!
#
# Gathering results for: suoyarvi
# Success! Results for suoyarvi added to dataframe!!
#
# Gathering results for: nguiu
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24588>)
#
# Gathering results for: eyemouth
# Success! Results for eyemouth added to dataframe!!
#
# Gathering results for: argelia
# Success! Results for argelia added to dataframe!!
#
# Gathering results for: comodoro rivadavia
# Success! Results for comodoro rivadavia added to dataframe!!
#
# Gathering results for: taguatinga
# Success! Results for taguatinga added to dataframe!!
#
# Gathering results for: yanan
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3AA48>)
#
# Gathering results for: saint-francois
# Success! Results for saint-francois added to dataframe!!
#
# Gathering results for: westport
# Success! Results for westport added to dataframe!!
#
# Gathering results for: ewa beach
# Success! Results for ewa beach added to dataframe!!
#
# Gathering results for: iisalmi
# Success! Results for iisalmi added to dataframe!!
#
# Gathering results for: poum
# Success! Results for poum added to dataframe!!
#
# Gathering results for: tala
# Success! Results for tala added to dataframe!!
#
# Gathering results for: zyryanka
# Success! Results for zyryanka added to dataframe!!
#
# Gathering results for: azimur
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF24E88>)
#
# Gathering results for: uglegorsk
# Success! Results for uglegorsk added to dataframe!!
#
# Gathering results for: shingu
# Success! Results for shingu added to dataframe!!
#
# Gathering results for: sorland
# Success! Results for sorland added to dataframe!!
# Gathering results for: knyaze-volkonskoye
# Success! Results for knyaze-volkonskoye added to dataframe!!
#
# Gathering results for: kingman
# Success! Results for kingman added to dataframe!!
#
# Gathering results for: shubarkuduk
# Success! Results for shubarkuduk added to dataframe!!
#
# Gathering results for: rocha
# Success! Results for rocha added to dataframe!!
#
# Gathering results for: egvekinot
# Success! Results for egvekinot added to dataframe!!
#
# Gathering results for: fort-shevchenko
# Success! Results for fort-shevchenko added to dataframe!!
#
# Gathering results for: pimenta bueno
# Success! Results for pimenta bueno added to dataframe!!
#
# Gathering results for: vittoria
# Success! Results for vittoria added to dataframe!!
#
# Gathering results for: broken hill
# Success! Results for broken hill added to dataframe!!
#
# Gathering results for: poya
# Success! Results for poya added to dataframe!!
#
# Gathering results for: crotone
# Success! Results for crotone added to dataframe!!
#
# Gathering results for: kyren
# Success! Results for kyren added to dataframe!!
#
# Gathering results for: bayan
# Success! Results for bayan added to dataframe!!
#
# Gathering results for: luganville
# Success! Results for luganville added to dataframe!!
#
# Gathering results for: tucuman
# Success! Results for tucuman added to dataframe!!
#
# Gathering results for: imbituba
# Success! Results for imbituba added to dataframe!!
#
# Gathering results for: aitape
# Success! Results for aitape added to dataframe!!
#
# Gathering results for: severo-kurilsk
# Success! Results for severo-kurilsk added to dataframe!!
#
# Gathering results for: diu
# Success! Results for diu added to dataframe!!
#
# Gathering results for: larsnes
# Success! Results for larsnes added to dataframe!!
#
# Gathering results for: miracema do tocantins
# Success! Results for miracema do tocantins added to dataframe!!
#
# Gathering results for: bozuyuk
# Success! Results for bozuyuk added to dataframe!!
#
# Gathering results for: falealupo
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3A9C8>)
#
# Gathering results for: pecos
# Success! Results for pecos added to dataframe!!
#
# Gathering results for: coquimbo
# Success! Results for coquimbo added to dataframe!!
#
# Gathering results for: elizabeth city
# Success! Results for elizabeth city added to dataframe!!
#
# Gathering results for: nossa senhora da gloria
# Success! Results for nossa senhora da gloria added to dataframe!!
#
# Gathering results for: yumen
# Success! Results for yumen added to dataframe!!
#
# Gathering results for: fershampenuaz
# Success! Results for fershampenuaz added to dataframe!!
#
# Gathering results for: poronaysk
# Success! Results for poronaysk added to dataframe!!
#
# Gathering results for: ixtapa
# Success! Results for ixtapa added to dataframe!!
#
# Gathering results for: ondorhaan
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954948>)
#
# Gathering results for: sambava
# Success! Results for sambava added to dataframe!!
#
# Gathering results for: toamasina
# Success! Results for toamasina added to dataframe!!
#
# Gathering results for: cam ranh
# Success! Results for cam ranh added to dataframe!!
#
# Gathering results for: porto murtinho
# Success! Results for porto murtinho added to dataframe!!
#
# Gathering results for: dymer
# Success! Results for dymer added to dataframe!!
#
# Gathering results for: puerto maldonado
# Success! Results for puerto maldonado added to dataframe!!
#
# Gathering results for: abhayapuri
# Success! Results for abhayapuri added to dataframe!!
#
# Gathering results for: smithers
# Success! Results for smithers added to dataframe!!
#
# Gathering results for: huarmey
# Success! Results for huarmey added to dataframe!!
#
# Gathering results for: barahona
# Success! Results for barahona added to dataframe!!
#
# Gathering results for: borovoy
# Success! Results for borovoy added to dataframe!!
#
# Gathering results for: jiuquan
# Success! Results for jiuquan added to dataframe!!
#
# Gathering results for: dmitriyevka
# Success! Results for dmitriyevka added to dataframe!!
#
# Gathering results for: salisbury
# Success! Results for salisbury added to dataframe!!
#
# Gathering results for: wuchang
# Success! Results for wuchang added to dataframe!!
#
# Gathering results for: port dickson
# Success! Results for port dickson added to dataframe!!
#
# Gathering results for: nizwa
# Success! Results for nizwa added to dataframe!!
#
# Gathering results for: sovetskaya
# Success! Results for sovetskaya added to dataframe!!
#
# Gathering results for: paita
# Success! Results for paita added to dataframe!!
#
# Gathering results for: abu dhabi
# Success! Results for abu dhabi added to dataframe!!
#
# Gathering results for: pemangkat
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF243C8>)
#
# Gathering results for: catalina
# Success! Results for catalina added to dataframe!!
#
# Gathering results for: kuala terengganu
# Success! Results for kuala terengganu added to dataframe!!
#
# Gathering results for: manaure
# Success! Results for manaure added to dataframe!!
#
# Gathering results for: urgut
# Success! Results for urgut added to dataframe!!
#
# Gathering results for: caucasia
# Success! Results for caucasia added to dataframe!!
#
# Gathering results for: skalistyy
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF3BD48>)
#
# Gathering results for: ambilobe
# Success! Results for ambilobe added to dataframe!!
#
# Gathering results for: mehtar lam
# Success! Results for mehtar lam added to dataframe!!
#
# Gathering results for: bratsk
# Success! Results for bratsk added to dataframe!!
#
# Gathering results for: faya
# Success! Results for faya added to dataframe!!
#
# Gathering results for: ankazoabo
# Success! Results for ankazoabo added to dataframe!!
#
# Gathering results for: wiarton
# Success! Results for wiarton added to dataframe!!
#
# Gathering results for: hirara
# Success! Results for hirara added to dataframe!!
#
# Gathering results for: port hedland
# Success! Results for port hedland added to dataframe!!
#
# Gathering results for: faranah
# Success! Results for faranah added to dataframe!!
#
# Gathering results for: nawa
# Success! Results for nawa added to dataframe!!
#
# Gathering results for: sahrak
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x0000000002954948>)
#
# Gathering results for: gopalpur
# Success! Results for gopalpur added to dataframe!!
#
# Gathering results for: yulara
# Success! Results for yulara added to dataframe!!
#
# Gathering results for: guozhen
# Success! Results for guozhen added to dataframe!!
#
# Gathering results for: dicabisagan
# Success! Results for dicabisagan added to dataframe!!
#
# Gathering results for: haibowan
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x00000000029567C8>)
#
# Gathering results for: dien bien
# Missing result ...skipping (<class 'KeyError'>, KeyError('clouds'), <traceback object at 0x000000000AF213C8>)
#
# Gathering results for: dingle
# Success! Results for dingle added to dataframe!!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities
#print check
# cities.to_csv("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/cities.csv")
# Out:
#                  City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0               amapa         75      HN  1553252400       94  15.09  -87.97
# 1            tasiilaq         80      GL  1553251800       85  65.61  -37.64
# 2          santa cruz         75      US  1553254093       93  36.97 -122.03
# 3            lorengau         88      PG  1553254126       97  -2.02  147.27
# 4                nome          1      US  1553254112       87  30.04  -94.42
# 5             ushuaia         90      AR  1553252400       87 -54.81  -68.31
# 6              touros         20      BR  1553252400      100   -5.2  -35.46
# 7          louisbourg
# 8           busselton          0      AU  1553254005       43 -33.64  115.35
# 9           jamestown         44      AU  1553254127       86 -33.21   138.6
# 10             narsaq         75      GL  1553251800       39  60.91  -46.05
# 11      ponta delgada         20      PT  1553254108       82  37.73  -25.67
# 12            kodinsk         92      RU  1553254128       72   58.6   99.18
# 13      srednekolymsk          0      RU  1553254128       38  67.46  153.71
# 14      tyret pervaya          0      RU  1553254128       79  53.67  102.31
# 15           saleaula
# 16          wattegama         56      LK  1553254129       95   7.35   80.68
# 17         burns lake         44      CA  1553254129       78  54.23 -125.76
# 18          kadykchan
# 19             yambio
# 20           cherskiy          0      RU  1553254130       30  68.75   161.3
# 21          hithadhoo         32      MV  1553254130      100   -0.6   73.08
# 22       norman wells         20      CA  1553252400       79  65.28 -126.83
# 23            usagara         20      TZ  1553248800       45  -2.68   32.99
# 24       punta arenas         75      CL  1553253794       81 -53.16  -70.91
# 25            mataura         88      NZ  1553253605       87 -46.19  168.86
# 26             pandan          0      PH  1553254131       94  11.72  122.09
# 27        port alfred         92      ZA  1553253874       76 -33.59   26.89
# 28              kapaa         40      US  1553254093       73  22.08 -159.32
# 29             matara         90      PE  1553252400       65 -13.74   -72.9
# ..                ...        ...     ...         ...      ...    ...     ...
# 595      port dickson         75      MY  1553252400       70   2.52  101.79
# 596             nizwa         88      OM  1553254280       17  22.93   57.53
# 597        sovetskaya         12      RU  1553254264        4  44.78   41.17
# 598             paita          0      PE  1553252400      290  -5.09  -81.11
# 599         abu dhabi          0      AE  1553251020       22  24.47   54.37
# 600         pemangkat
# 601          catalina         20      CO  1553254281       84   8.86  -75.38
# 602  kuala terengganu         75      MY  1553248800       66   5.33  103.14
# 603           manaure         56      CO  1553254281       95  11.78  -72.45
# 604             urgut         75      UZ  1553250600       58  39.41   67.25
# 605          caucasia         80      CO  1553254282       97   7.98   -75.2
# 606         skalistyy
# 607          ambilobe         64      MG  1553254282       89 -13.19   49.05
# 608        mehtar lam         20      AF  1553252100       17  34.67   70.21
# 609            bratsk          8      RU  1553253794       63  56.15  101.63
# 610              faya         40      SA  1553252400       28  18.39   42.45
# 611         ankazoabo         32      MG  1553254283       63 -22.29   44.51
# 612           wiarton         90      CA  1553254146       86  44.74  -81.13
# 613            hirara         75      JP  1553248800       83   24.8  125.28
# 614      port hedland         80      AU  1553250600       70 -20.31  118.58
# 615           faranah         92      GN  1553254284       83  10.04  -10.74
# 616              nawa          0      IN  1553254284       14  27.02      75
# 617            sahrak
# 618          gopalpur          0      IN  1553254285       30   25.6   86.94
# 619            yulara         20      AU  1553252400       13 -25.24  130.99
# 620           guozhen         92      CN  1553254285      100   29.3  113.14
# 621       dicabisagan          0      PH  1553254286      100  17.08  122.42
# 622          haibowan
# 623         dien bien
# 624            dingle         20      PH  1553254286       50     11  122.67
#
#     Max Temp Wind Speed
# 0     295.15       1.11
# 1     265.15        2.1
# 2     282.59        1.5
# 3     301.48       4.31
# 4     286.48       1.21
# 5     280.15        2.6
# 6     299.15        2.1
# 7
# 8     290.93      11.21
# 9     290.43       1.41
# 10    261.15        6.7
# 11    289.15        2.6
# 12    274.93       4.66
# 13    248.68       1.31
# 14    268.28       2.96
# 15
# 16    297.78       0.86
# 17    270.48       0.96
# 18
# 19
# 20    243.68       1.31
# 21    303.03       2.86
# 22    266.15        7.2
# 23    303.15        5.1
# 24    282.15        5.1
# 25    290.37       2.86
# 26    300.78       5.36
# 27    297.04       0.45
# 28    296.15        5.7
# 29    281.15       0.56
# ..       ...        ...
# 595   304.15        4.1
# 596   304.03       2.11
# 597   281.48      10.73
# 598   290.15        4.1
# 599   305.15        3.6
# 600
# 601   297.28       2.41
# 602   305.15        3.6
# 603   297.78       5.61
# 604   288.15        3.1
# 605   296.78       1.31
# 606
# 607   301.78       1.46
# 608   297.15        1.5
# 609   273.15          4
# 610   297.15        7.2
# 611   302.38       1.96
# 612   274.26        4.1
# 613   296.15        6.7
# 614   304.15        7.7
# 615   298.28       3.76
# 616   302.83       4.31
# 617
# 618   304.18       4.56
# 619   307.15        3.6
# 620   281.78       4.46
# 621   295.18       2.16
# 622
# 623
# 624   301.13       5.11
#
# [625 rows x 9 columns]

# %%
#Clean dataframe for graphs
cities.replace("", np.nan, inplace=True)
cities_cleaned = cities.dropna(how="any")
cities_cleaned
# Out:
#                  City  Cloudiness Country          Date  Humidity    Lat  \
# 0               amapa        75.0      HN  1.553252e+09      94.0  15.09
# 1            tasiilaq        80.0      GL  1.553252e+09      85.0  65.61
# 2          santa cruz        75.0      US  1.553254e+09      93.0  36.97
# 3            lorengau        88.0      PG  1.553254e+09      97.0  -2.02
# 4                nome         1.0      US  1.553254e+09      87.0  30.04
# 5             ushuaia        90.0      AR  1.553252e+09      87.0 -54.81
# 6              touros        20.0      BR  1.553252e+09     100.0  -5.20
# 8           busselton         0.0      AU  1.553254e+09      43.0 -33.64
# 9           jamestown        44.0      AU  1.553254e+09      86.0 -33.21
# 10             narsaq        75.0      GL  1.553252e+09      39.0  60.91
# 11      ponta delgada        20.0      PT  1.553254e+09      82.0  37.73
# 12            kodinsk        92.0      RU  1.553254e+09      72.0  58.60
# 13      srednekolymsk         0.0      RU  1.553254e+09      38.0  67.46
# 14      tyret pervaya         0.0      RU  1.553254e+09      79.0  53.67
# 16          wattegama        56.0      LK  1.553254e+09      95.0   7.35
# 17         burns lake        44.0      CA  1.553254e+09      78.0  54.23
# 20           cherskiy         0.0      RU  1.553254e+09      30.0  68.75
# 21          hithadhoo        32.0      MV  1.553254e+09     100.0  -0.60
# 22       norman wells        20.0      CA  1.553252e+09      79.0  65.28
# 23            usagara        20.0      TZ  1.553249e+09      45.0  -2.68
# 24       punta arenas        75.0      CL  1.553254e+09      81.0 -53.16
# 25            mataura        88.0      NZ  1.553254e+09      87.0 -46.19
# 26             pandan         0.0      PH  1.553254e+09      94.0  11.72
# 27        port alfred        92.0      ZA  1.553254e+09      76.0 -33.59
# 28              kapaa        40.0      US  1.553254e+09      73.0  22.08
# 29             matara        90.0      PE  1.553252e+09      65.0 -13.74
# 31               lasa        20.0      CY  1.553253e+09      64.0  34.92
# 33          upernavik        32.0      GL  1.553254e+09     100.0  72.79
# 34            husavik         0.0      CA  1.553254e+09      91.0  50.56
# 35             dikson         8.0      RU  1.553254e+09      98.0  73.51
# ..                ...         ...     ...           ...       ...    ...
# 590           borovoy        56.0      RU  1.553254e+09      88.0  63.23
# 591           jiuquan         0.0      CN  1.553254e+09      64.0  39.73
# 592       dmitriyevka        88.0      GE  1.553254e+09     100.0  43.08
# 593         salisbury        90.0      GB  1.553254e+09      81.0  51.07
# 594           wuchang        56.0      CN  1.553254e+09      67.0  44.93
# 595      port dickson        75.0      MY  1.553252e+09      70.0   2.52
# 596             nizwa        88.0      OM  1.553254e+09      17.0  22.93
# 597        sovetskaya        12.0      RU  1.553254e+09       4.0  44.78
# 598             paita         0.0      PE  1.553252e+09     290.0  -5.09
# 599         abu dhabi         0.0      AE  1.553251e+09      22.0  24.47
# 601          catalina        20.0      CO  1.553254e+09      84.0   8.86
# 602  kuala terengganu        75.0      MY  1.553249e+09      66.0   5.33
# 603           manaure        56.0      CO  1.553254e+09      95.0  11.78
# 604             urgut        75.0      UZ  1.553251e+09      58.0  39.41
# 605          caucasia        80.0      CO  1.553254e+09      97.0   7.98
# 607          ambilobe        64.0      MG  1.553254e+09      89.0 -13.19
# 608        mehtar lam        20.0      AF  1.553252e+09      17.0  34.67
# 609            bratsk         8.0      RU  1.553254e+09      63.0  56.15
# 610              faya        40.0      SA  1.553252e+09      28.0  18.39
# 611         ankazoabo        32.0      MG  1.553254e+09      63.0 -22.29
# 612           wiarton        90.0      CA  1.553254e+09      86.0  44.74
# 613            hirara        75.0      JP  1.553249e+09      83.0  24.80
# 614      port hedland        80.0      AU  1.553251e+09      70.0 -20.31
# 615           faranah        92.0      GN  1.553254e+09      83.0  10.04
# 616              nawa         0.0      IN  1.553254e+09      14.0  27.02
# 618          gopalpur         0.0      IN  1.553254e+09      30.0  25.60
# 619            yulara        20.0      AU  1.553252e+09      13.0 -25.24
# 620           guozhen        92.0      CN  1.553254e+09     100.0  29.30
# 621       dicabisagan         0.0      PH  1.553254e+09     100.0  17.08
# 624            dingle        20.0      PH  1.553254e+09      50.0  11.00
#
#         Lng  Max Temp  Wind Speed
# 0    -87.97    295.15        1.11
# 1    -37.64    265.15        2.10
# 2   -122.03    282.59        1.50
# 3    147.27    301.48        4.31
# 4    -94.42    286.48        1.21
# 5    -68.31    280.15        2.60
# 6    -35.46    299.15        2.10
# 8    115.35    290.93       11.21
# 9    138.60    290.43        1.41
# 10   -46.05    261.15        6.70
# 11   -25.67    289.15        2.60
# 12    99.18    274.93        4.66
# 13   153.71    248.68        1.31
# 14   102.31    268.28        2.96
# 16    80.68    297.78        0.86
# 17  -125.76    270.48        0.96
# 20   161.30    243.68        1.31
# 21    73.08    303.03        2.86
# 22  -126.83    266.15        7.20
# 23    32.99    303.15        5.10
# 24   -70.91    282.15        5.10
# 25   168.86    290.37        2.86
# 26   122.09    300.78        5.36
# 27    26.89    297.04        0.45
# 28  -159.32    296.15        5.70
# 29   -72.90    281.15        0.56
# 31    32.53    295.15        1.00
# 33   -56.15    247.93        2.86
# 34   -96.99    268.71        1.26
# 35    80.55    256.48        3.41
# ..      ...       ...         ...
# 590   52.89    274.73        2.31
# 591   98.49    268.38        1.11
# 592   41.00    276.03        1.16
# 593   -1.80    284.26        2.10
# 594  127.16    263.03        2.66
# 595  101.79    304.15        4.10
# 596   57.53    304.03        2.11
# 597   41.17    281.48       10.73
# 598  -81.11    290.15        4.10
# 599   54.37    305.15        3.60
# 601  -75.38    297.28        2.41
# 602  103.14    305.15        3.60
# 603  -72.45    297.78        5.61
# 604   67.25    288.15        3.10
# 605  -75.20    296.78        1.31
# 607   49.05    301.78        1.46
# 608   70.21    297.15        1.50
# 609  101.63    273.15        4.00
# 610   42.45    297.15        7.20
# 611   44.51    302.38        1.96
# 612  -81.13    274.26        4.10
# 613  125.28    296.15        6.70
# 614  118.58    304.15        7.70
# 615  -10.74    298.28        3.76
# 616   75.00    302.83        4.31
# 618   86.94    304.18        4.56
# 619  130.99    307.15        3.60
# 620  113.14    281.78        4.46
# 621  122.42    295.18        2.16
# 624  122.67    301.13        5.11
#
# [567 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis = cities_cleaned["Lat"]
y_axis = cities_cleaned["Max Temp"]

plt.scatter(x_axis,y_axis, color = "blue", edgecolor="black")
plt.title("City Latitude vs. Max Temperature (03/21/2019)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid(linestyle="dotted")

# Save Figure

plt.savefig("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/Lat vs. Temp.png",bbox_inches=("tight"))
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x_axis = cities_cleaned["Lat"]
y_axis = cities_cleaned["Humidity"]
plt.scatter(x_axis,y_axis)

plt.scatter(x_axis,y_axis, color = "blue", edgecolor="black")
plt.title("City Latitude vs. Humidity (03/21/2019)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(linestyle="dotted")

# Save Figure

plt.savefig("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/Lat vs. Humidity.png",bbox_inches=("tight"))
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x_axis = cities_cleaned["Lat"]
y_axis = cities_cleaned["Cloudiness"]
plt.scatter(x_axis,y_axis)

plt.scatter(x_axis,y_axis, color = "blue", edgecolor="black")
plt.title("City Latitude vs. Cloudiness (03/21/2019)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(linestyle="dotted")

# Save Figure
plt.savefig("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/Lat vs. Cloudiness.png",bbox_inches=("tight"))
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x_axis = cities_cleaned["Lat"]
y_axis = cities_cleaned["Wind Speed"]
plt.scatter(x_axis,y_axis)

plt.scatter(x_axis,y_axis, color = "blue", edgecolor="black")
plt.title("City Latitude vs. Wind Speed (03/21/2019)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(linestyle="dotted")

# Save Figure
plt.savefig("C:/Users/kapali_s/Documents/SMU/Homeworks/Assignment_6/Lat vs. Wind Speed.png",bbox_inches=("tight"))
plt.show()
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>
